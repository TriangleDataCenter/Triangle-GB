# %%
import numpy as np
try:  
    import cupy as xp  
    USE_GPU = True 
except ImportError:  
    import numpy as xp 
    print('No Cupy')
    USE_GPU = False 

import matplotlib.pyplot as plt
from tqdm import tqdm

# to mute the warnings of lal 
import warnings
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
import lal

from Triangle.Constants import *
from Triangle.FFTTools import *
from Triangle.Noise import *
from Triangle.Orbit import *
from Triangle.Data import * 
from Triangle.GW import * 
from Triangle.TDI import * 

import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['font.family'] = 'serif'

# np.random.seed(114514)
# Out:
# No Cupy
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1

# %% [markdown]
# ## Useful functions

# %%
class GBToolkits: 
    @classmethod
    def frequency_band(cls, f0, Tobs, single_side_pad_frac=1./4.):
        """  
        Args: 
            f0: central frequency of the target band
            Tobs: total observation time 
            single_side_pad_band: the fraction to be padded at both sides 
        Returns: 
            the lower, upper limits of the frequency band, both before and after padding 
        """
        df_chirp = 2.542e-10 * (Tobs / YEAR) * (f0 / 1e-3) ** (11/3) # the const. factors are calculated based on the mass limit of WDs 
        df_doppler = 9.935e-8 * (f0 / 1e-3)
        fmin = f0 - df_doppler
        fmax = f0 + df_chirp + df_doppler
        pad_band = (fmax - fmin) * single_side_pad_frac
        fmin_pad = fmin - pad_band
        fmax_pad = fmax + pad_band
        return fmin, fmax, fmin_pad, fmax_pad

    @classmethod
    def frequency_derivative_range(cls, f0):
        """ 
            Calculate the frequency evolution caused by GW emission. 
            These expressions do not apply to DWDs with mass transfer, whose fdot may be negative. 
        """
        dfmin = 1.209e-9 * f0 ** (11/3) 
        dfmax = 8.055e-7 * f0 ** (11/3)
        return dfmin, dfmax

    @classmethod
    def get_fddot(cls, f, fdot):
        return 11.0 / 3.0 * fdot ** 2 / f

    @classmethod
    def Params2VecParams(cls, params):
        """  
            convert params of shape (9, Nevents) to (Nevents, 8)
            the original params are: A, f0, fdot, fddot, phase0, iota, psi, lambda, beta (to be passed to GBGPU)
            the converted params are: lgA, f0, fdot, phase0, cosiota, psi, lambda, sinbeta (to be passed to ERYN)
        """
        p = np.transpose(params.copy()) # (Nevents, Nparams=9)
        p[:, 0] = np.log10(p[:, 0]) # lgA
        p[:, 5] = np.cos(p[:, 5]) # cos iota 
        p[:, 8] = np.sin(p[:, 8]) # sin beta 
        ind_list = [0, 1, 2, 4, 5, 6, 7, 8] # remove fddot 
        return p[:, ind_list] # (Nevents, Nparams=8)

    @classmethod
    def VecParams2Params(cls, vecparams):
        """  
            convert params of shape (Nevents, 8) to (9, Nevents)
            the original params are: lgA, f0, fdot, phase0, cosiota, psi, lambda, sinbeta
            the converted params are: A, f0, fdot, fddot, phase0, iota, psi, lambda, beta
        """
        p = np.zeros((9, vecparams.shape[0])) # (Nparams=9, Nevents)
        p[0:3] = np.transpose(vecparams[:, 0:3])
        p[4:9] = np.transpose(vecparams[:, 3:8])
        p[0] = np.power(10, p[0]) # lgA to A 
        p[3] = cls.get_fddot(f=p[1], fdot=p[2]) # fddot 
        p[5] = np.arccos(p[5]) # cos iota to iota 
        p[8] = np.arcsin(p[8]) # sin beta to beta 
        return p # (Nparams=9, Nevents)

    @classmethod
    def loglikelihood(cls, vecparams, gb, dt, Tobs, data_channels, data_PSDs, df, cutinds, Npoints=1024):
        """  
        Args: 
            vecparmas: params of shape (Nevents, 8) 
            gb: an initialized GBGPU object (use_gpu should be True)
            dt: the sampling cadance in second 
            Tobs: total observation time in second 
            data_channels: frequency-domain data of shape (2, Nfreqs), 2 for AE
            data_PSDs: PSD of shape (2, Nfreqs)
            df: frequency resolution of data 
            cutinds: index of used data in the whole array of Fourier frequencies 
            Npoints: number of points calculated by GBGPU, usually 512 is enough for a several-year data  
        Returns: 
            vectorized log likelihood
        """
        # convert parameters 
        params = cls.VecParams2Params(vecparams=vecparams)
        
        # calculate waveforms
        gb.run_wave(*params, dt=dt, T=Tobs, N=Npoints, oversample=4, tdi2=True)
        
        # fill into templates
        Nevents = len(vecparams)
        wf_templates = xp.zeros((Nevents, 2, len(cutinds)), dtype=xp.complex128)
        gb.fill_global_template(group_index=xp.arange(Nevents), templates=wf_templates, A=gb.A, E=gb.E, start_inds=gb.start_inds, start_freq_ind=cutinds[0], N=Npoints)
        
        # calculate likelihood array 
        if USE_GPU:
            return (-2. * df * xp.sum(xp.sum(xp.abs(wf_templates - data_channels) ** 2 / data_PSDs, axis=-1), axis=-1)).get()
        else: 
            return (-2. * df * xp.sum(xp.sum(xp.abs(wf_templates - data_channels) ** 2 / data_PSDs, axis=-1), axis=-1))

# %% [markdown]
# ## Load TDC data and combine TDI channels

# %%
h5filename = "/Volumes/RubbishBin/TDC2_GWData/5_h5datasets/verification_dataset_vgb.h5"
with h5py.File(h5filename, "r") as h5file: 
    data_dict = read_dict_from_h5(h5file["/"])
print("raw data:", data_dict.keys())

orbitfilename = "/Users/taijidatacenter/workspace/FakeData/OrbitData/MicroSateOrbitEclipticTCB"
orbit_for_ltts = Orbit(OrbitDir=orbitfilename)
ltts = dict() 
for key in MOSA_labels: 
    ltts[key] = orbit_for_ltts.LTTfunctions()[key](data_dict["time"])
ltts = MOSADict(ltts)
m = {"eta" : data_dict["eta"]}
fsample = 1. / (data_dict["time"][1] - data_dict["time"][0])
tdi = TDI(measurements=m, delays=ltts, fsample=fsample, order=31) 
tdi.FastMichelson(channel="AET", doppler=True)
print("tdi data:", tdi.measurements.keys())

# drop the invalid points at the edges 
channel_names = ["A2", "E2", "T2"]
drop_points = int(fsample * 1500.)
for channel_name in channel_names: 
    tdi.measurements[channel_name][:drop_points] *= 0. 
    tdi.measurements[channel_name][-drop_points:] *= 0.
# Out:
# raw data: dict_keys(['eta', 'parameters', 'time'])
# tdi data: dict_keys(['eta', 'dpl', 'X0', 'X1', 'X2', 'Y0', 'Y1', 'Y2', 'Z0', 'Z1', 'Z2', 'A0', 'E0', 'T0', 'A1', 'E1', 'T1', 'A2', 'E2', 'T2'])

# %%
channel_names = ["A2", "E2"] # use AE only hereafter 

for channel_name in channel_names:
    plt.plot(data_dict["time"][drop_points:-drop_points], tdi.measurements[channel_name][drop_points:-drop_points], label=channel_name)
plt.xlabel("Time (s)")
plt.ylabel("TDI")
plt.legend(loc="upper left")

# %%
# the window parameters will be global settings
win_type = "tukey"
win_alpha = 0.05
win_factor = 0.97 # this is only an empirical value 

ff, xf = PSD_window(data_dict["eta"]["12"], fsample=fsample, nbin=1, window_type=win_type, window_args_dict=dict(alpha=win_alpha))
plt.loglog(ff, np.sqrt(xf), label=r"$\eta_{12}$")

for channel_name in channel_names: 
    ff, xf = PSD_window(tdi.measurements[channel_name], fsample=fsample, nbin=1, window_type=win_type, window_args_dict=dict(alpha=win_alpha))
    plt.loglog(ff, np.sqrt(xf), label="TDI-"+channel_name)
PSDfunc = TDIPSDs()
plt.loglog(ff, np.sqrt(PSDfunc.PSD_A2(ff)), linestyle="--", color='k')
plt.ylim(1e-25,)
plt.xlim(1e-4, 0.1)
plt.legend(loc="center left")
plt.xlabel("Frequency (Hz)")
plt.ylabel("ASD "+r"$({\rm Hz^{-1/2}})$")
# Out:
# Text(0, 0.5, 'ASD $({\\rm Hz^{-1/2}})$')

# %% [markdown]
# ## select frequency band

# %%
vgb_idx = 5 # select the 5th source as an example 

parameters = dict()
for k, v in data_dict["parameters"].items(): 
    parameters[k] = v[vgb_idx]

central_frequency = parameters["f0"]

parameters
# Out:
# {'A': 6.374598302504699e-23,
#  'f0': 0.006220278731,
#  'fdot0': -1.955518638e-17,
#  'inclination': 0.6632425823152799,
#  'latitude': -0.08212462497747364,
#  'longitude': 2.10205239901753,
#  'phase0': 4.573550034925289,
#  'psi': 2.860203781647726}

# %%
# set metadata 
Tobs = data_dict["time"][-1] - data_dict["time"][0]
dt = data_dict["time"][1] - data_dict["time"][0]
print('Tobs [day], dt [s]:', Tobs/DAY, dt)

# load data and convert to frequency-domain data 
data_channels = []
for i, k in enumerate(channel_names):
    ff, xff = FFT_window(
        tdi.measurements[k], 
        fsample, 
        window_type=win_type, 
        window_args_dict=dict(alpha=win_alpha)
        )
    data_channels.append(np.concatenate(([0.], xff)) / win_factor) # add a DC term to match the convension of xp.fft.rfft
data_channels = xp.array(data_channels)
data_frequency = xp.array(np.concatenate(([0.], ff)))

# remove data outside the frequency bin 
fmin, fmax, fmin_pad, fmax_pad = GBToolkits.frequency_band(f0=central_frequency, Tobs=Tobs, single_side_pad_frac=0.5)
# fmin, fmax, fmin_pad, fmax_pad = central_frequency - 1e-6, central_frequency + 1e-6, central_frequency - 2e-6, central_frequency + 2e-6
cutinds = xp.where((data_frequency <= fmax_pad)&(data_frequency >= fmin_pad))[0]
data_channels_cut = xp.array([data_channels[i][cutinds] for i in range(len(data_channels))])
data_frequency_cut = data_frequency[cutinds]
df = data_frequency_cut[1] - data_frequency_cut[0]

print("df [Hz], data shape:", df, data_channels_cut.shape)
# Out:
# Tobs [day], dt [s]: 109.99998842592592 1.0
# df [Hz], data shape: 1.0521885521891372e-07 (2, 25)

# %% [markdown]
# ### estimate noise PSD

# %%
# calculate PSD using the left and right intervals where there are no signals 
# this is kind of ad-hoc, and should be updated for true global fits 
f_interval = fmax_pad - fmin_pad 
f_leftmin = fmin_pad - f_interval
f_leftmax = fmin_pad
f_rightmin = fmax_pad 
f_rightmax = fmax_pad + f_interval 
ind_psd_left = xp.where((data_frequency >= f_leftmin)&(data_frequency <= f_leftmax))[0]
ind_psd_right = xp.where((data_frequency >= f_rightmin)&(data_frequency <= f_rightmax))[0]
ind_psd_tot = xp.concatenate((ind_psd_left, ind_psd_right))
mean_psd_A = xp.mean(xp.abs(data_channels[0][ind_psd_tot]) ** 2 * 2. / Tobs) # calculate PSD with periodgram 
mean_psd_E = xp.mean(xp.abs(data_channels[1][ind_psd_tot]) ** 2 * 2. / Tobs) 
data_PSDs_cut = xp.ones_like(data_channels_cut, dtype=xp.float64) # model PSDs as constants since the frequency bin is relatively small 
data_PSDs_cut[0] *= mean_psd_A
data_PSDs_cut[1] *= mean_psd_E
print("estimated ASDs:", np.sqrt(mean_psd_A), np.sqrt(mean_psd_E))
# Out:
# estimated ASDs: 3.015536537180707e-21 3.1646197891076897e-21

# %%
plt.figure(figsize=(10, 5))
channel_colors = ["skyblue", "magenta"]
for i, (channel_name, channel_color) in enumerate(zip(channel_names, channel_colors)):
    if USE_GPU:
        plt.plot(data_frequency_cut.get(), np.abs(data_channels_cut[i].get()), label=channel_name, color=channel_color)
    else: 
        plt.plot(data_frequency_cut, np.abs(data_channels_cut[i]), label=channel_name, color=channel_color)
if USE_GPU:
    plt.vlines(central_frequency, np.min(np.abs(data_channels_cut.get())), np.max(np.abs(data_channels_cut.get())), linestyle='--', color='k', label=r'central frequency', linewidth=1)
else: 
    plt.vlines(central_frequency, np.min(np.abs(data_channels_cut)), np.max(np.abs(data_channels_cut)), linestyle='--', color='k', label=r'central frequency', linewidth=1)
plt.legend(loc="upper right")
plt.grid(linestyle=':')
plt.xlabel("Frequency (Hz)")
plt.ylabel("Fourier-domain waveform")
# Out:
# Text(0, 0.5, 'Fourier-domain waveform')

# %% [markdown]
# ## Initialize GB model by GBGPU

# %%
from gbgpu.gbgpu import GBGPU
from gbgpu.utils.constants import *
from gbgpu.utils.utility import *
# Out:
# /Users/taijidatacenter/miniconda3/envs/triangle/lib/python3.9/site-packages/gbgpu-0.1-py3.9-macosx-11.0-arm64.egg/gbgpu/gbgpu.py:25: UserWarning: tdi module not found. No sensitivity information will be included.
#   warnings.warn("tdi module not found. No sensitivity information will be included.")
# /Users/taijidatacenter/miniconda3/envs/triangle/lib/python3.9/site-packages/gbgpu-0.1-py3.9-macosx-11.0-arm64.egg/gbgpu/utils/utility.py:15: UserWarning: tdi module not found. No sensitivity information will be included.
#   warnings.warn("tdi module not found. No sensitivity information will be included.")

# %%
Npoints = 512

gb = GBGPU(
    use_gpu=USE_GPU, 
    orbit_file=orbitfilename,
    unequal_arm=True,
    )

# %% [markdown]
# ## Test waveform modeling with the fiducial parameters
# ``NOTE`` that in principle we should stay ignorant of the true parameters when doing blind search.

# %%
# manipulate parameters
amp = parameters['A']  # amplitude
f0 = parameters['f0']  # f0
fdot = parameters['fdot0']  # fdot
fddot = GBToolkits.get_fddot(f=f0, fdot=fdot)
phi0 = parameters['phase0']  # initial phase
iota = parameters['inclination']  # inclination
psi = parameters['psi']  # polarization angle
lam = parameters['longitude']  # ecliptic longitude
beta_sky = parameters['latitude']  # ecliptic latitude

amp_in = np.atleast_1d(amp)
f0_in = np.atleast_1d(f0)
fdot_in = np.atleast_1d(fdot)
fddot_in = np.atleast_1d(fddot)
phi0_in = np.atleast_1d(phi0)
iota_in = np.atleast_1d(iota)
psi_in = np.atleast_1d(psi)
lam_in = np.atleast_1d(lam)
beta_sky_in = np.atleast_1d(beta_sky)

params = np.array(
    [amp_in, f0_in, fdot_in, fddot_in, phi0_in, iota_in, psi_in, lam_in, beta_sky_in,]
)

vecparams = GBToolkits.Params2VecParams(params)
print("fiducial parameters:", vecparams)

# calculate waveforms 
gb.run_wave(*params, N=Npoints, dt=dt, T=Tobs, oversample=4, tdi2=True)

# fill into the full fourier templates 
wf_templates = xp.zeros((1, 2, len(cutinds)), dtype=xp.complex128)
gb.fill_global_template(group_index=xp.array([0,]), templates=wf_templates, A=gb.A, E=gb.E, start_inds=gb.start_inds, start_freq_ind=cutinds[0], N=Npoints)
# Out:
# fiducial parameters: [[-2.21955472e+01  6.22027873e-03 -1.95551864e-17  4.57355003e+00
#    7.88000000e-01  2.86020378e+00  2.10205240e+00 -8.20323418e-02]]

# %%
plt.figure(figsize=(10, 5))

for i, (channel_name, channel_color) in enumerate(zip(channel_names, channel_colors)): 
    if USE_GPU:
        plt.plot(data_frequency_cut.get(), np.abs(data_channels_cut[i].get()), label='TDI-'+channel_name+', data', color=channel_color, alpha=1, linewidth=1)
        plt.plot(data_frequency_cut.get(), np.abs(wf_templates[0][i].get()), label='TDI-'+channel_name+', template', color=channel_color, linestyle=':', linewidth=2)
        plt.plot(data_frequency_cut.get(), np.sqrt(data_PSDs_cut[i].get() * Tobs / 2.), color=channel_color, alpha=0.5)
    else: 
        plt.plot(data_frequency_cut, np.abs(data_channels_cut[i]), label='TDI-'+channel_name+', data', color=channel_color, alpha=1, linewidth=1)
        plt.plot(data_frequency_cut, np.abs(wf_templates[0][i]), label='TDI-'+channel_name+', template', color=channel_color, linestyle=':', linewidth=2)
        plt.plot(data_frequency_cut, np.sqrt(data_PSDs_cut[i] * Tobs / 2.), color=channel_color, alpha=0.5)

if USE_GPU:
    plt.vlines(central_frequency, np.min(np.abs(data_channels_cut.get())), np.max(np.abs(data_channels_cut.get())), linestyle='--', color='k', label=r'central frequency', linewidth=1)
else: 
    plt.vlines(central_frequency, np.min(np.abs(data_channels_cut)), np.max(np.abs(data_channels_cut)), linestyle='--', color='k', label=r'central frequency', linewidth=1)

plt.legend(loc="upper right")
plt.grid(linestyle=':')
plt.xlabel("Frequency (Hz)")
plt.ylabel("Fourier-domain waveform")
# Out:
# Text(0, 0.5, 'Fourier-domain waveform')

# %% [markdown]
# ## Test likelihood around the true values
# This is only a test for the waveform and likelihood.
# The peak value of loglikelihood would not be at the truth since the data is noisy.

# %%
# test the freuqnecy parameter 
test_n = 1001
test_freqs = np.linspace(-1e-7, 1e-7, test_n) + vecparams[0][1]
test_vecparams = np.zeros((test_n, vecparams.shape[1]))
for i in range(test_n):
    test_vecparams[i] = vecparams.copy()
    test_vecparams[i][1] = test_freqs[i]
test_ll = GBToolkits.loglikelihood(test_vecparams, gb, dt, Tobs, data_channels_cut, data_PSDs_cut, df, cutinds, Npoints)

plt.plot(test_freqs, test_ll)
plt.vlines(vecparams[0][1], min(test_ll), max(test_ll), color='k', linestyle='--')
plt.xlabel(r'$f_0$'+' (Hz)')
plt.ylabel('log likelihood')
# Out:
# Text(0, 0.5, 'log likelihood')

# %% [markdown]
# ## PE with Eryn MCMC

# %%
from eryn.ensemble import EnsembleSampler
from eryn.state import State
from eryn.prior import ProbDistContainer, uniform_dist
from eryn.utils import TransformContainer
from eryn.moves import GaussianMove, StretchMove, CombineMove
from eryn.utils.utility import groups_from_inds
from eryn.backends import HDFBackend
from eryn.utils import SearchConvergeStopping

import corner

# %%
# hyper parameters
ndim = 8
nwalkers = 100
ntemps = 10
if ntemps == 1:
    temps = np.array([1.])
else:
    temps = np.array(list(np.power(2., np.arange(ntemps - 1))) + [np.infty])
betas = 1. / temps 
tempering_kwargs=dict(betas=betas)

# priors
# These priors are rather conservative. Hopefully they can be better constrained by some astrophysical reasons? 
lim_lgA = [-24, -20] # this should be broad enough?
lim_f0 = np.array([fmin, fmax]) # only the unpadded range 
lim_df0 = np.array([-1e-15, 1e-15]) # the prior in GBToolkits only applies to DWDs with no mass transfer (thus df0 > 0), thus we set a relatively broad range here 
lim_phi0 = [0, TWOPI] # should be periodic in principle 
lim_cosinc = [-1, 1] 
lim_psi = [0, PI]
lim_lam = [0, TWOPI] # should be periodic in principle 
lim_sinbeta = [-1, 1]

lims = [lim_lgA, lim_f0, lim_df0, lim_phi0, lim_cosinc, lim_psi, lim_lam, lim_sinbeta]

priors_in = {i: uniform_dist(lims[i][0], lims[i][1]) for i in range(ndim)}
priors = ProbDistContainer(priors_in)
priors.use_cupy = False

# %%
# set emcee move 
Emceemoves = StretchMove(a=2) # 2 by default
stop = None 

# initialize sampler 
init_ensemble = EnsembleSampler(
    nwalkers,
    ndim,
    GBToolkits.loglikelihood,
    priors,
    args=[gb, dt, Tobs, data_channels_cut, data_PSDs_cut, df, cutinds, Npoints],
    tempering_kwargs=tempering_kwargs,
    stopping_fn=None,
    moves=Emceemoves,
    vectorize=True,
)

# set backend file 
chain_filename='./Chains/MCMC_'+str(vgb_idx)+'.h5'
backend = HDFBackend(chain_filename)
backend.reset(nwalkers=nwalkers, ndims=ndim, ntemps=ntemps, moves=init_ensemble.backend.move_keys)
print('args of the backend =', backend.reset_args)
print('move keys =', backend.move_keys)
print('Initialization flag of backend =', backend.initialized)


ensemble = EnsembleSampler(
    nwalkers,
    ndim,
    GBToolkits.loglikelihood,
    priors,
    args=[gb, dt, Tobs, data_channels_cut, data_PSDs_cut, df, cutinds, Npoints],
    tempering_kwargs=tempering_kwargs,
    stopping_fn=None,
    moves=init_ensemble.moves,
    backend=backend,
    vectorize=True,
)
# Out:
# args of the backend = [100, {'model_0': 8}]
# move keys = ['StretchMove_0']
# Initialization flag of backend = True

# %%
# starting positions
# randomize throughout prior
coords = priors.rvs(size=(ntemps, nwalkers,))
print("shape of starting points:", coords.shape)

thin_by =100
burn = 0
nsteps = int(100000 / thin_by)

ensemble.stopping_fn = None

out = ensemble.run_mcmc(coords, nsteps, burn=burn, progress=True, thin_by=thin_by)
# Out:
# shape of starting points: (10, 100, 8)
#   4%|▍         | 4151/100000 [19:37<8:25:00,  3.16it/s]

# %% [markdown]
# ### resume run if necessary

# %%
# ensemble.stopping_fn = None
thin_by =100
burn = 0
nsteps = int(100000 / thin_by)

out = ensemble.run_mcmc(ensemble.get_last_sample(), nsteps, burn=burn, progress=True, thin_by=thin_by)
# Out:
#  70%|███████   | 70169/100000 [11:09<04:43, 105.25it/s]Traceback (most recent call last):
#   File "/home/ps/miniconda3/envs/taiji_data/lib/python3.9/site-packages/eryn/ensemble.py", line 1584, in __call__
#     out = self.f(*args_in, **kwargs_in)
#   File "/tmp/ipykernel_208541/1167286300.py", line 85, in loglikelihood
#     gb.run_wave(*params, dt=dt, T=Tobs, N=Npoints, oversample=4, tdi2=True)
#   File "/home/ps/miniconda3/envs/taiji_data/lib/python3.9/site-packages/gbgpu-0.1-py3.9-linux-x86_64.egg/gbgpu/gbgpu.py", line 325, in run_wave
#     Gs, q, arm_length_PN = self._construct_slow_part(
#   File "/home/ps/miniconda3/envs/taiji_data/lib/python3.9/site-packages/gbgpu-0.1-py3.9-linux-x86_64.egg/gbgpu/gbgpu.py", line 659, in _construct_slow_part
#     0.25
# KeyboardInterrupt
#  70%|███████   | 70172/100000 [11:09<04:44, 104.79it/s]
# eryn: Exception while calling your likelihood function:
#   args added: [array([[-2.21727492e+01,  6.22027719e-03, -2.59798401e-17, ...,
#          2.95243121e+00,  2.10787316e+00, -5.84123082e-02],
#        [-2.22444611e+01,  6.22027957e-03, -4.01212849e-16, ...,
#          9.47400255e-01,  2.10640590e+00, -9.51455786e-02],
#        [-2.22619439e+01,  6.22027238e-03,  3.25874381e-16, ...,
#          1.27726196e+00,  2.11132566e+00, -4.49408384e-02],
#        ...,
#        [-2.06996885e+01,  6.22015353e-03,  7.13105791e-16, ...,
#          1.24825314e-01,  3.35398148e+00,  6.57706289e-01],
#        [-2.10534018e+01,  6.22026433e-03, -1.17189428e-16, ...,
#          2.57818498e+00,  2.03489785e+00, -1.79697140e-01],
#        [-2.29604387e+01,  6.22055477e-03, -6.72934225e-16, ...,
#          1.54273154e+00,  1.89625663e+00,  2.54171094e-01]])]
#   args: [<gbgpu.gbgpu.GBGPU object at 0x7e4e1f12ad30>, 1.0, 9503999.0, array([[ 1.11821614e-19-1.32768499e-17j,  7.35106359e-18-1.13579169e-17j,
#          1.15109030e-17-1.39815687e-17j,  4.50662201e-18-8.71258603e-18j,
#          1.36251022e-17-1.84244883e-17j,  7.01401668e-18-2.17686714e-17j,
#          3.53980809e-17-2.54152216e-17j,  6.74259141e-17+2.59214098e-17j,
#          1.14394212e-17+1.13938862e-16j, -1.34212391e-16-3.30680045e-18j,
#          8.91019552e-17-7.13542508e-17j, -1.08813513e-16+6.81812216e-17j,
#          1.15737561e-16-1.68322250e-17j, -7.43944728e-17-1.21518761e-16j,
#         -1.13630532e-16+2.66867767e-17j, -4.24443157e-17+6.71562756e-17j,
#          4.48978666e-18+4.73974280e-17j,  1.22851260e-17+2.60945763e-17j,
#          1.18620610e-17+1.52089496e-17j,  1.04052835e-17+6.76976569e-18j,
#          5.84394585e-18-1.96861488e-19j,  3.47101847e-18+5.85828314e-19j,
#          8.98957223e-18-1.49651882e-18j,  5.46981025e-18-1.15147733e-18j,
#          2.66488285e-18+5.81989006e-18j],
#        [ 7.79857588e-18+2.44849128e-18j, -6.92236419e-19+2.80866034e-18j,
#          9.24102445e-18+4.40039282e-20j,  9.00989962e-18-6.11158602e-18j,
#          9.68605388e-18+4.88325119e-21j,  1.65589404e-17+1.26454014e-17j,
#          3.12430359e-17+2.79408330e-17j, -1.34160199e-17+5.99400965e-17j,
#         -8.18334333e-17+1.81574769e-17j,  4.09231230e-18-1.10635209e-16j,
#          6.26642256e-17+8.05333627e-17j, -5.14704739e-17-9.55386050e-17j,
#          1.93724501e-17+1.07111705e-16j,  1.15358472e-16-5.81511941e-17j,
#         -2.11617863e-17-1.08320533e-16j, -5.55750656e-17-3.61878873e-17j,
#         -4.89569769e-17+2.11547489e-19j, -2.81681958e-17+1.33898446e-17j,
#         -1.78056902e-17+9.91939134e-18j, -1.12354639e-17+8.14120153e-18j,
#         -2.50783003e-18+3.42461900e-18j, -1.74847702e-18+6.83431348e-18j,
#         -3.35552705e-18+7.66670671e-18j,  2.05665629e-18-3.13183804e-19j,
#         -3.04051669e-18+5.77164085e-18j]]), array([[9.09346152e-42, 9.09346152e-42, 9.09346152e-42, 9.09346152e-42,
#         9.09346152e-42, 9.09346152e-42, 9.09346152e-42, 9.09346152e-42,
#         9.09346152e-42, 9.09346152e-42, 9.09346152e-42, 9.09346152e-42,
#         9.09346152e-42, 9.09346152e-42, 9.09346152e-42, 9.09346152e-42,
#         9.09346152e-42, 9.09346152e-42, 9.09346152e-42, 9.09346152e-42,
#         9.09346152e-42, 9.09346152e-42, 9.09346152e-42, 9.09346152e-42,
#         9.09346152e-42],
#        [1.00148180e-41, 1.00148180e-41, 1.00148180e-41, 1.00148180e-41,
#         1.00148180e-41, 1.00148180e-41, 1.00148180e-41, 1.00148180e-41,
#         1.00148180e-41, 1.00148180e-41, 1.00148180e-41, 1.00148180e-41,
#         1.00148180e-41, 1.00148180e-41, 1.00148180e-41, 1.00148180e-41,
#         1.00148180e-41, 1.00148180e-41, 1.00148180e-41, 1.00148180e-41,
#         1.00148180e-41, 1.00148180e-41, 1.00148180e-41, 1.00148180e-41,
#         1.00148180e-41]]), array(1.05218855e-07), array([59106, 59107, 59108, 59109, 59110, 59111, 59112, 59113, 59114,
#        59115, 59116, 59117, 59118, 59119, 59120, 59121, 59122, 59123,
#        59124, 59125, 59126, 59127, 59128, 59129, 59130]), 512]
#   kwargs added: {}
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 6
#       3 burn = 0
#       4 nsteps = int(100000 / thin_by)
# ----> 6 out = ensemble.run_mcmc(ensemble.get_last_sample(), nsteps, burn=burn, progress=True, thin_by=thin_by)
#
# File ~/miniconda3/envs/taiji_data/lib/python3.9/site-packages/eryn/ensemble.py:1040, in EnsembleSampler.run_mcmc(self, initial_state, nsteps, burn, post_burn_update, **kwargs)
#    1037 results = None
#    1039 i = 0
# -> 1040 for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#    1041     # diagnostic plots
#    1042     # TODO: adjust diagnostic plots
#    1043     if self.plot_iterations > 0 and (i + 1) % (self.plot_iterations) == 0:
#    1044         self.plot_generator.generate_plot_info()  # TODO: remove defaults
#
# File ~/miniconda3/envs/taiji_data/lib/python3.9/site-packages/eryn/ensemble.py:902, in EnsembleSampler.sample(self, initial_state, iterations, tune, skip_initial_state_check, thin_by, store, progress)
#     899 move = self._random.choice(self.moves, p=self.weights)
#     901 # Propose (in model)
# --> 902 state, accepted_out = move.propose(model, state)
#     903 accepted += accepted_out
#     904 if self.ntemps > 1:
#
# File ~/miniconda3/envs/taiji_data/lib/python3.9/site-packages/eryn/moves/red_blue.py:268, in RedBlueMove.propose(self, model, state)
#     265 self.fix_logp_gibbs(branch_names_run, inds_run, logp, real_inds_subset)
#     267 # Compute the lnprobs of the proposed position.
# --> 268 logl, new_blobs = model.compute_log_like_fn(
#     269     q,
#     270     inds=new_inds,
#     271     logp=logp,
#     272     supps=new_supps,
#     273     branch_supps=new_branch_supps,
#     274 )
#     276 # catch and warn about nans
#     277 if np.any(np.isnan(logl)):
#
# File ~/miniconda3/envs/taiji_data/lib/python3.9/site-packages/eryn/ensemble.py:1340, in EnsembleSampler.compute_log_like(self, coords, inds, logp, supps, branch_supps)
#    1337     args_and_kwargs = (args_in, kwargs_in)
#    1339     # get vectorized results
# -> 1340     results = self.log_like_fn(args_and_kwargs)
#    1342 # each Likelihood is computed individually
#    1343 else:
#    1344     # if groups in is an array, need to put it in a list.
#    1345     if isinstance(groups_in, np.ndarray):
#
# File ~/miniconda3/envs/taiji_data/lib/python3.9/site-packages/eryn/ensemble.py:1584, in _FunctionWrapper.__call__(self, args_and_kwargs)
#    1581     args_in = args_in_add + type(args_in_add)(self.args)
#    1582     kwargs_in = {**kwargs_in_add, **self.kwargs}
# -> 1584     out = self.f(*args_in, **kwargs_in)
#    1585     return out
#    1587 except:  # pragma: no cover
#
# Cell In[2], line 85, in GBToolkits.loglikelihood(cls, vecparams, gb, dt, Tobs, data_channels, data_PSDs, df, cutinds, Npoints)
#      82 params = cls.VecParams2Params(vecparams=vecparams)
#      84 # calculate waveforms
# ---> 85 gb.run_wave(*params, dt=dt, T=Tobs, N=Npoints, oversample=4, tdi2=True)
#      87 # fill into templates
#      88 Nevents = len(vecparams)
#
# File ~/miniconda3/envs/taiji_data/lib/python3.9/site-packages/gbgpu-0.1-py3.9-linux-x86_64.egg/gbgpu/gbgpu.py:325, in GBGPU.run_wave(self, amp, f0, fdot, fddot, phi0, iota, psi, lam, beta, N, T, dt, oversample, tdi2, *args)
#     322 Ps = self._spacecraft(tm)
#     324 # time domain information
# --> 325 Gs, q, arm_length_PN = self._construct_slow_part(
#     326     T,
#     327     Larm,
#     328     Ps,
#     329     # Vels,
#     330     tm,
#     331     f0,
#     332     fdot,
#     333     fddot,
#     334     fstar,
#     335     phi0,
#     336     k,
#     337     DP,
#     338     DC,
#     339     eplus,
#     340     ecross,
#     341     *add_args,
#     342 )
#     344 # transform to TDI observables
#     345 XYZf, f_min = self._computeXYZ(T, Gs, f0, fdot, fddot, fstar, amp, q, tm, tdi2, arm_length_PN)
#
# File ~/miniconda3/envs/taiji_data/lib/python3.9/site-packages/gbgpu-0.1-py3.9-linux-x86_64.egg/gbgpu/gbgpu.py:659, in GBGPU._construct_slow_part(self, T, arm_length, Ps, tm, f0, fdot, fddot, fstar, phi0, k, DP, DC, eplus, ecross, *add_args)
#     656     else:
#     657         arg_ij = 0.5 * fonfs[:, s, :] * (1 + kdotr[ij])
#     658     Gs[ij] = (
# --> 659         0.25
#     660         * self.xp.sin(arg_ij)
#     661         / arg_ij
#     662         * self.xp.exp(-1.0j * (arg_ij + kdotP[:, s]))
#     663         * A[ij_sym]
#     664     )
#     665 ### Lines blow are extractions from another python code and from C-code in LDC
#     666 # y = -0.5j*self.omL*A*sinc(args)*np.exp(-1.0j*(args + self.om*kq))
#     667 # args = 0.5*self.omL*(1.0 - kn)
#    (...)
#     677 # wfm->TR[i][j] = sinc*(tran1r*tran2r - tran1i*tran2i)
#     678 # wfm->TI[i][j] = sinc*(tran1r*tran2i + tran1i*tran2r)
#     679 return Gs, q, arm_length_PN
#
# KeyboardInterrupt:

# %% [markdown]
# ## Monitor MCMC run

# %%
param_labels = [r'${\rm lg}A$', r'$f_0$', r'$\dot{f}_0$', r'$\varphi_0$', r'$\cos \iota$', r'$\psi$', r'$\lambda$', r'$\sin \beta$']
param_truths = vecparams[0]

# %%
reader = HDFBackend(chain_filename, read_only=True)
samples = reader.get_chain(discard=0, thin=1)
raw_sample = samples['model_0'][:, :, :, 0, :]
nstep = raw_sample.shape[0]
ntemp = raw_sample.shape[1]
nwalker = raw_sample.shape[2]
ndim = raw_sample.shape[3]

raw_sample = None
print(nstep, ntemp, nwalker, ndim)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 reader = HDFBackend(chain_filename, read_only=True)
#       2 samples = reader.get_chain(discard=0, thin=1)
#       3 raw_sample = samples['model_0'][:, :, :, 0, :]
#
# NameError: name 'chain_filename' is not defined

# %%
thin = 10
burnin = 0
len_chain = len(reader.get_chain(thin=thin, discard=burnin)['model_0'][:, 0, 0, :, 0])

fig, ax = plt.subplots(ndim, 1)
fig.set_size_inches(10, 3*ndim)
for i in range(ndim):
    for walk in range(20):
    # for walk in range(nwalker):
        ax[i].plot(reader.get_chain(thin=thin, discard=burnin)['model_0'][:, 0, walk, 0, i])
        ax[i].hlines(param_truths[i], 0, len_chain, color='k', linestyle='-.', linewidth=1)
    ax[i].set_ylabel(param_labels[i])

# %% [markdown]
# ## Plot posterior

# %%
burnin=200 # set according to the chains
thin = 10

samp = reader.get_chain(discard=burnin, thin=thin)['model_0'][:, 0, :, :, :].reshape(-1, ndim)

masks = [True for _ in param_labels]
# masks[3] = False
# masks[2] = False
# masks[6] = False

figure = corner.corner(
    samp[:, masks], bins=30, color=BLUE, 
    # range = lims, # comment this line to plot smaller ranges
    labels=np.array(param_labels)[masks], label_kwargs={'fontsize': 14}, 
    truths=np.array(param_truths)[masks], truth_color=RED, 
    quantiles=[0.16, 0.5, 0.84],
    show_titles=True, title_kwargs={'fontsize':14},
    levels = (1. - np.exp(-1.**2/2), 1. - np.exp(-2.**2/2), ), # 2-sigmas
    smooth=0.5
    );
