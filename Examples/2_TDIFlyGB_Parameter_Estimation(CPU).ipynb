# %% [markdown]
# ## Demonstrate parameter estimation of GB signal
# - Data: TDC II-0.1 verification dataset with VGBs (download links: [data](https://zenodo.org/records/15469724/files/0_1_VGB_TDIXYZ.h5?download=1), [parameters](https://zenodo.org/records/15532090/files/0_1_VGB_parameters.h5?download=1)).
# - Template: ``TDIFly`` waveform model
# - Methods: ``NESSAI`` nested sampler implemented in ``BILBY``
#
# NOTE that this example doesn't require the installation of ``Triangle-GB``.

# %%
import os

os.environ["OMP_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"
os.environ["VECLIB_MAXIMUM_THREADS"] = "1"

from Triangle.Constants import *
from Triangle.FFTTools import *
from Triangle.Noise import *
from Triangle.Orbit import *
from Triangle.Data import *
from Triangle.TDI import *
from Triangle.GW import *
from Triangle.TDIFly import * 

import matplotlib
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.family'] = 'serif'
import matplotlib.pyplot as plt

import multiprocessing
if __name__ == "__main__":
    multiprocessing.set_start_method("fork")
# Out:
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1
# no cupy

# %%
DATA_DIR = "/Users/taijidatacenter/workspace/TDCData/0_1_VGB_TDIXYZ.h5"
PARAM_DIR = "/Users/taijidatacenter/workspace/TDCData/0_1_VGB_parameters.h5"
ORBIT_DIR = "../../Triangle-Simulator/OrbitData/MicroSateOrbitEclipticTCB"

# %% [markdown]
# ## Load TDI data and true parameters

# %% [markdown]
# ### Time-domain data and parameters

# %%
with h5py.File(DATA_DIR, "r") as h5file: 
    data_dict = read_dict_from_h5(h5file["/"])

with h5py.File(PARAM_DIR, "r") as h5file: 
    inject_parameters = read_dict_from_h5(h5file["/"])

data_dict.keys(), inject_parameters.keys()
# Out:
# (dict_keys(['XYZ', 'time']),
#  dict_keys(['A', 'f0', 'fdot0', 'inclination', 'latitude', 'longitude', 'phase0', 'psi']))

# %%
dt = data_dict["time"][1] - data_dict["time"][0]

# pad data to start from t=0
data_time_pad = np.arange(start=0., stop=data_dict["time"][0], step=dt)
data_time = np.concatenate((data_time_pad, data_dict["time"]))

Tobs = len(data_time) * dt 

A_data, E_data, _ = AETfromXYZ(data_dict["XYZ"]["X2"], data_dict["XYZ"]["Y2"], data_dict["XYZ"]["Z2"])
data_channels_td = np.zeros((2, len(data_time)))
data_channels_td[0][len(data_time_pad):] = A_data
data_channels_td[1][len(data_time_pad):] = E_data

channel_names = ["A", "E"]

# %%
for i in range(len(data_channels_td)):
    plt.plot(data_time/DAY, data_channels_td[i], label=channel_names[i])
plt.xlabel("Time (day)")
plt.ylabel("TDI")
plt.legend(loc="upper left")

# %% [markdown]
# ### Fourier transform

# %%
data_channels_fd = [] 
for i in range(len(data_channels_td)): 
    ff, xf = FFT_window(
        data_array=data_channels_td[i], 
        fsample=1./dt, 
        window_type="tukey", 
        window_args_dict=dict(alpha=10000/Tobs), 
    )
    data_channels_fd.append(xf)
data_frequency = ff 
data_channels_fd = np.array(data_channels_fd)

# %%
for i in range(len(data_channels_fd)):
    plt.loglog(data_frequency, np.abs(data_channels_fd[i]), label=channel_names[i]) 
plt.xlabel("Frequency (Hz)")
plt.ylabel("TDI (1/Hz)")
plt.legend(loc="upper left")
plt.xlim(1e-4, 0.05)
# Out:
# (0.0001, 0.05)

# %% [markdown]
# ### select a freuqncy band to be analyzed

# %%
# select a GB to analyze
analyze_gb_idx = 1

true_gb_parameters = {key: inject_parameters[key][analyze_gb_idx] for key in inject_parameters.keys()} 
true_gb_parameters
# Out:
# {'A': 9.402415441563616e-23,
#  'f0': 0.0048216991071498,
#  'fdot0': 2.53782494976533e-16,
#  'inclination': 1.4686945655532282,
#  'latitude': 1.1547376242549767,
#  'longitude': 3.578406556800828,
#  'phase0': 2.680478779022586,
#  'psi': 2.4599687248082027}

# %%
band_width = 5e-6

band_idx = np.where((data_frequency <= true_gb_parameters["f0"] + band_width/2)&(data_frequency >= true_gb_parameters["f0"] - band_width/2))[0]
data_frequency = data_frequency[band_idx]
data_channels_fd = data_channels_fd[:, band_idx]

# %%
PSDlevel = np.mean(np.median(np.abs(data_channels_fd) ** 2 * 2. / Tobs, axis=1))

# %%
for i in range(len(data_channels_fd)):
    plt.semilogy(data_frequency*1e3, np.abs(data_channels_fd[i]), label=channel_names[i]) 
plt.hlines(np.sqrt(PSDlevel* Tobs / 2.), data_frequency[0]*1e3, data_frequency[-1]*1e3, colors="k", linestyles="--", label="noise level")
plt.xlabel("Frequency (mHz)")
plt.ylabel("TDI (1/Hz)")
plt.legend(loc="upper left")

# %% [markdown]
# ## Waveform template model

# %%
orbit = Orbit(OrbitDir=ORBIT_DIR)

X2_strings = TDIFly.X2_strings
Y2_strings = TDIStringManipulation.TDIStringCyc(X2_strings)
Z2_strings = TDIStringManipulation.TDIStringCyc(Y2_strings)

gb_tdifly_generator = TDIFlyGB(
    orbit=orbit, 
    Pstring_list=[X2_strings, Y2_strings, Z2_strings], 
    tcb_times=data_time.copy(), 
    Nsparse=512,
    use_gpu=False, 
)

# %% [markdown]
# ## Likelihood and priors

# %% [markdown]
# ### Likelihood wrapper
# $${\rm ln}\mathcal{L}(\boldsymbol{\theta}) = -\frac{1}{2}\langle d - h(\boldsymbol{\theta}) | d - h(\boldsymbol{\theta}) \rangle$$

# %%
import bilby 

class bilby_likelihood_wrapper(bilby.Likelihood):
    def __init__(self):
        super().__init__(
            parameters={
                'A': None,
                'f0': None,
                'fdot0': None,
                'inclination': None,
                'latitude': None,
                'longitude': None,
                'phase0': None,
                'psi': None,
            }
        )

    def log_likelihood(self):
        return gb_tdifly_generator.Likelihood(
            data=data_channels_fd, 
            parameters=self.parameters, 
            StartBound=band_idx[0]+1, 
            EndBound=band_idx[-1]+1, 
            Tobs=Tobs, 
            S=PSDlevel, 
        )[0]

# %% [markdown]
# ### Prior
# For the 4 "intrinsic" parameters, we use the same range as example 2. Notice that for some case $\dot{f}_0$ should also include negative values.

# %%
priors = bilby.core.prior.PriorDict()
priors["A"] = bilby.prior.LogUniform(minimum=1e-23, maximum=1e-20, name='A', latex_label='$A$')
priors["f0"] = bilby.prior.Uniform(minimum=data_frequency[0], maximum=data_frequency[-1], name="f0", latex_label='$f_0$')
priors["fdot0"] = bilby.prior.Uniform(minimum=0, maximum=TDIFlyGB.fdot_upper_bound(data_frequency[0]), name="fdot0", latex_label='$\dot{f}_0$')
priors["inclination"] = bilby.prior.Sine(minimum=0., maximum=PI, name="inclination", latex_label='$\iota$')
priors["latitude"] = bilby.prior.Cosine(minimum=-PI/2., maximum=PI/2., name="latitude", latex_label='$\\beta$')
priors["longitude"] = bilby.prior.Uniform(minimum=0., maximum=TWOPI, name="longitude", latex_label='$\lambda$', boundary="periodic")
priors["phase0"] = bilby.prior.Uniform(minimum=0., maximum=TWOPI, name="phase0", latex_label='$\\varphi_0$', boundary="periodic")
priors["psi"] = bilby.prior.Uniform(minimum=0., maximum=PI, name="psi", latex_label='$\psi$', boundary="periodic")
priors
# Out:
# {'A': LogUniform(minimum=1e-23, maximum=1e-20, name='A', latex_label='$A$', unit=None, boundary=None),
#  'f0': Uniform(minimum=0.004819210879598371, maximum=0.004824167705958519, name='f0', latex_label='$f_0$', unit=None, boundary=None),
#  'fdot0': Uniform(minimum=0, maximum=3.193339396586594e-15, name='fdot0', latex_label='$\\dot{f}_0$', unit=None, boundary=None),
#  'inclination': Sine(minimum=0.0, maximum=3.141592653589793, name='inclination', latex_label='$\\iota$', unit=None, boundary=None),
#  'latitude': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='latitude', latex_label='$\\beta$', unit=None, boundary=None),
#  'longitude': Uniform(minimum=0.0, maximum=6.283185307179586, name='longitude', latex_label='$\\lambda$', unit=None, boundary='periodic'),
#  'phase0': Uniform(minimum=0.0, maximum=6.283185307179586, name='phase0', latex_label='$\\varphi_0$', unit=None, boundary='periodic'),
#  'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}

# %% [markdown]
# ## Parameter estimation

# %%
BLike = bilby_likelihood_wrapper()

ncpu = multiprocessing.cpu_count()
print("number of cpus =", ncpu)

result = bilby.run_sampler(
    likelihood=BLike, 
    priors=priors,
    sampler="nessai", 
    # nlive=2000, # seems that nlive=500 is OK
    nlive=500,
    stopping=0.01, 
    npool=ncpu, # use all cpus 
    injection_parameters=true_gb_parameters, 
    outdir="./Samples",
    label="vgb_example",
    plot=True,
    resume=False, 
    # resume=True, 
)
# Out:
# 12:25 bilby INFO    : Running for label 'vgb_example', output will be saved to './Samples'
# number of cpus = 12
# /Users/taijidatacenter/miniconda3/envs/tri_env/lib/python3.9/site-packages/bilby/core/utils/log.py:73: UserWarning: The '__version__' attribute is deprecated and will be removed in MarkupSafe 3.1. Use feature detection, or `importlib.metadata.version("markupsafe")`, instead.
#   vdict[key] = str(getattr(sys.modules[key], "__version__", "N/A"))
# 12:25 bilby INFO    : Analysis priors:
# 12:25 bilby INFO    : A=LogUniform(minimum=1e-23, maximum=1e-20, name='A', latex_label='$A$', unit=None, boundary=None)
# 12:25 bilby INFO    : f0=Uniform(minimum=0.004819210879598371, maximum=0.004824167705958519, name='f0', latex_label='$f_0$', unit=None, boundary=None)
# 12:25 bilby INFO    : fdot0=Uniform(minimum=0, maximum=3.193339396586594e-15, name='fdot0', latex_label='$\\dot{f}_0$', unit=None, boundary=None)
# 12:25 bilby INFO    : inclination=Sine(minimum=0.0, maximum=3.141592653589793, name='inclination', latex_label='$\\iota$', unit=None, boundary=None)
# 12:25 bilby INFO    : latitude=Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='latitude', latex_label='$\\beta$', unit=None, boundary=None)
# 12:25 bilby INFO    : longitude=Uniform(minimum=0.0, maximum=6.283185307179586, name='longitude', latex_label='$\\lambda$', unit=None, boundary='periodic')
# 12:25 bilby INFO    : phase0=Uniform(minimum=0.0, maximum=6.283185307179586, name='phase0', latex_label='$\\varphi_0$', unit=None, boundary='periodic')
# 12:25 bilby INFO    : psi=Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')
# 12:25 bilby INFO    : Analysis likelihood class: <class '__main__.bilby_likelihood_wrapper'>
# 12:25 bilby INFO    : Analysis likelihood noise evidence: nan
# 12:25 bilby INFO    : Single likelihood evaluation took nan s
# 12:25 bilby INFO    : Using sampler Nessai with kwargs {'n_steps': 10, 'n_accept': None, 'step_type': 'gaussian', 'step_kwargs': None, 'plot_chain': False, 'plot_history': False, 'enforce_likelihood_threshold': True, 'ensemble_fraction': 0.5, 'rng': None, 'flow_config': None, 'training_config': None, 'output': './Samples/vgb_example_nessai/', 'poolsize': 1000, 'plot': True, 'check_acceptance': False, 'max_poolsize_scale': 10, 'update_poolsize': True, 'accumulate_weights': False, 'save_training_data': False, 'reparameterisations': None, 'fallback_reparameterisation': 'zscore', 'use_default_reparameterisations': None, 'reverse_reparameterisations': False, 'map_to_unit_hypercube': False, 'max_n_clusters': None, 'latent_prior': 'truncated_gaussian', 'constant_volume_mode': True, 'volume_fraction': 0.95, 'fuzz': 1.0, 'fixed_radius': False, 'drawsize': None, 'truncate_log_q': False, 'expansion_fraction': 4.0, 'min_radius': False, 'max_radius': 50.0, 'compute_radius_with_all': False, 'augment_dims': 1, 'generate_augment': 'gaussian', 'marginalise_augment': False, 'n_marg': 50, 'nlive': 500, 'stopping': 0.01, 'max_iteration': None, 'checkpointing': True, 'checkpoint_interval': 600, 'checkpoint_on_iteration': False, 'checkpoint_on_training': False, 'checkpoint_callback': None, 'logging_interval': 60, 'log_on_iteration': False, 'resume_file': 'nested_sampler_resume.pkl', 'seed': None, 'pool': None, 'close_pool': None, 'n_pool': 12, 'proposal_plots': False, 'prior_sampling': False, 'analytic_priors': False, 'maximum_uninformed': None, 'uninformed_proposal': None, 'uninformed_acceptance_threshold': None, 'uninformed_proposal_kwargs': None, 'flow_proposal_class': None, 'flow_class': None, 'training_frequency': None, 'train_on_empty': True, 'cooldown': 200, 'memory': False, 'reset_weights': False, 'reset_permutations': False, 'reset_flow': False, 'retrain_acceptance': True, 'reset_acceptance': False, 'acceptance_threshold': 0.01, 'shrinkage_expectation': 'logt', 'trace_parameters': None, 'resume': False, 'resume_data': None, 'weights_file': None, 'weights_path': None, 'exit_code': 130, 'pytorch_threads': 1, 'eps': None, 'torch_dtype': None, 'disable_vectorisation': False, 'likelihood_chunksize': None, 'allow_multi_valued_likelihood': None, 'parallelise_prior': None, 'result_extension': 'hdf5', 'plot_indices': True, 'plot_posterior': False, 'plot_logXlogL': True, 'posterior_sampling_method': None, 'nessai_log_level': None, 'nessai_logging_stream': 'stdout', 'nessai_plot': True, 'nessai_likelihood_constraint': True}
# 01-25 12:25 nessai INFO    : Running Nessai version 0.14.0.post0
# 01-25 12:25 nessai INFO    : Starting multiprocessing pool with 12 processes
# /Users/taijidatacenter/miniconda3/envs/tri_env/lib/python3.9/site-packages/nessai/utils/logging.py:133: FutureWarning: setup_logger is deprecated, use configure_logger instead
#   warnings.warn(
# 01-25 12:25 nessai INFO    : Initialising nested sampler
# 01-25 12:25 nessai WARNING : Multiprocessing pool has already been configured.
# 01-25 12:25 nessai WARNING : Removing unused keyword arguments ({'step_type', 'augment_dims', 'enforce_likelihood_threshold', 'max_n_clusters', 'plot_history', 'n_accept', 'n_steps', 'step_kwargs', 'n_marg', 'plot_chain', 'ensemble_fraction', 'marginalise_augment', 'generate_augment'}) from kwargs for FlowProposal. These are valid keyword arguments but correspond to other proposal classes.
# 01-25 12:25 nessai INFO    : Passing kwargs to FlowProposal: {'training_config': None, 'poolsize': 1000, 'check_acceptance': False, 'max_poolsize_scale': 10, 'update_poolsize': True, 'accumulate_weights': False, 'save_training_data': False, 'reparameterisations': None, 'fallback_reparameterisation': 'zscore', 'use_default_reparameterisations': None, 'reverse_reparameterisations': False, 'map_to_unit_hypercube': False, 'latent_prior': 'truncated_gaussian', 'constant_volume_mode': True, 'volume_fraction': 0.95, 'fuzz': 1.0, 'fixed_radius': False, 'drawsize': None, 'truncate_log_q': False, 'expansion_fraction': 4.0, 'min_radius': False, 'max_radius': 50.0, 'compute_radius_with_all': False}
# 01-25 12:25 nessai WARNING : Signal handling is disabled. nessai will not automatically checkpoint when exited.
# 01-25 12:25 nessai INFO    : No reparameterisations provided, using default reparameterisations included in FlowProposal
# 01-25 12:25 nessai INFO    : Adding reparameterisations from: {}
# 01-25 12:25 nessai INFO    : Assuming fallback reparameterisation (ScaleAndShift) for ['A', 'f0', 'fdot0', 'inclination', 'latitude', 'longitude', 'phase0', 'psi'] with kwargs: {'estimate_scale': True, 'estimate_shift': True, 'prior_bounds': {'A': array([1.e-23, 1.e-20]), 'f0': array([0.00481921, 0.00482417]), 'fdot0': array([0.0000000e+00, 3.1933394e-15]), 'inclination': array([0.        , 3.14159265]), 'latitude': array([-1.57079633,  1.57079633]), 'longitude': array([0.        , 6.28318531]), 'phase0': array([0.        , 6.28318531]), 'psi': array([0.        , 3.14159265])}}.
# 01-25 12:25 nessai INFO    : x space parameters: ['A', 'f0', 'fdot0', 'inclination', 'latitude', 'longitude', 'phase0', 'psi']
# 01-25 12:25 nessai INFO    : x prime space parameters: ['A_prime', 'f0_prime', 'fdot0_prime', 'inclination_prime', 'latitude_prime', 'longitude_prime', 'phase0_prime', 'psi_prime']
# 01-25 12:25 nessai INFO    : Overwriting fuzz factor with expansion fraction
# 01-25 12:25 nessai INFO    : New fuzz factor: 1.2228445449938519
# 01-25 12:25 nessai INFO    : Verifying rescaling functions
# 01-25 12:25 nessai INFO    : Rescaling functions are invertible
# 01-25 12:25 nessai INFO    : Populating initial live points
# 01-25 12:25 nessai INFO    : Populated 50 / 500 live points
# 01-25 12:25 nessai INFO    : Populated 100 / 500 live points
# 01-25 12:25 nessai INFO    : Populated 150 / 500 live points
# 01-25 12:25 nessai INFO    : Populated 200 / 500 live points
# 01-25 12:25 nessai INFO    : Populated 250 / 500 live points
# 01-25 12:25 nessai INFO    : Populated 300 / 500 live points
# 01-25 12:25 nessai INFO    : Populated 350 / 500 live points
# 01-25 12:25 nessai INFO    : Populated 400 / 500 live points
# 01-25 12:25 nessai INFO    : Populated 450 / 500 live points
# 01-25 12:25 nessai INFO    : Populated 500 / 500 live points
# 01-25 12:25 nessai INFO    : Starting nested sampling loop
# 01-25 12:25 nessai INFO    : it:   500: Rolling KS test: D=0.02, p-value=0.6615
# 01-25 12:25 nessai INFO    : it:  1000: Rolling KS test: D=0.02, p-value=0.6615
# 01-25 12:25 nessai INFO    : Switching to FlowProposal
# 01-25 12:25 nessai INFO    : it:  1500: Rolling KS test: D=0.052, p-value=0.06463
# 01-25 12:25 nessai INFO    : it:  2000: Rolling KS test: D=0.022, p-value=0.6074
# 01-25 12:25 nessai INFO    : it:  2500: Rolling KS test: D=0.012, p-value=0.859
# 01-25 12:25 nessai INFO    : it:  3000: Rolling KS test: D=0.042, p-value=0.1666
# 01-25 12:25 nessai INFO    : it:  3500: Rolling KS test: D=0.042, p-value=0.1666
# 01-25 12:25 nessai INFO    : it:  4000: Rolling KS test: D=0.05, p-value=0.07937
# 01-25 12:26 nessai INFO    : it:  4500: Rolling KS test: D=0.044, p-value=0.1401
# 01-25 12:26 nessai INFO    : it:  4608: n eval: 119822 H: 12.55 dlogZ: 616.562 logZ: -2901.367 +/- 0.158 logLmax: -2275.59
# 01-25 12:26 nessai INFO    : it:  5000: Rolling KS test: D=0.026, p-value=0.5
# 01-25 12:26 nessai INFO    : it:  5500: Rolling KS test: D=0.032, p-value=0.3517
# 01-25 12:27 nessai INFO    : it:  6000: Rolling KS test: D=0.062, p-value=0.02051
# 01-25 12:27 nessai INFO    : it:  6364: n eval: 259822 H: 16.49 dlogZ: 1777.703 logZ: -2531.338 +/- 0.182 logLmax: -740.91
# 01-25 12:27 nessai INFO    : it:  6500: Rolling KS test: D=0.036, p-value=0.2672
# 01-25 12:27 nessai INFO    : it:  7000: Rolling KS test: D=0.064, p-value=0.01591
# 01-25 12:27 nessai INFO    : it:  7500: Rolling KS test: D=0.034, p-value=0.3078
# 01-25 12:28 nessai INFO    : it:  8000: Rolling KS test: D=0.02, p-value=0.6615
# 01-25 12:28 nessai INFO    : it:  8271: n eval: 409822 H: 21.40 dlogZ: 1156.255 logZ: -1913.704 +/- 0.207 logLmax: -740.91
# 01-25 12:28 nessai INFO    : it:  8500: Rolling KS test: D=0.022, p-value=0.6074
# 01-25 12:28 nessai INFO    : it:  9000: Rolling KS test: D=0.042, p-value=0.1666
# 01-25 12:28 nessai INFO    : it:  9500: Rolling KS test: D=0.024, p-value=0.5533
# 01-25 12:29 nessai INFO    : it: 10000: Rolling KS test: D=0.044, p-value=0.1401
# 01-25 12:29 nessai INFO    : it: 10365: n eval: 558763 H: 24.65 dlogZ: 656.162 logZ: -1144.794 +/- 0.222 logLmax: -467.90
# 01-25 12:29 nessai INFO    : it: 10500: Rolling KS test: D=0.054, p-value=0.0522
# 01-25 12:29 nessai INFO    : it: 11000: Rolling KS test: D=0.064, p-value=0.01591
# 01-25 12:29 nessai INFO    : it: 11500: Rolling KS test: D=0.008, p-value=0.933
# 01-25 12:29 nessai INFO    : it: 12000: Rolling KS test: D=0.02, p-value=0.6615
# 01-25 12:29 nessai INFO    : it: 12500: Rolling KS test: D=0.02, p-value=0.6615
# 01-25 12:30 nessai INFO    : it: 13000: Rolling KS test: D=0.02, p-value=0.6615
# 01-25 12:30 nessai INFO    : it: 13423: n eval: 696485 H: 29.92 dlogZ: 153.047 logZ: -517.482 +/- 0.245 logLmax: -337.59
# 01-25 12:30 nessai INFO    : it: 13500: Rolling KS test: D=0.034, p-value=0.3078
# 01-25 12:30 nessai INFO    : it: 14000: Rolling KS test: D=0.05, p-value=0.07937
# 01-25 12:30 nessai INFO    : it: 14500: Rolling KS test: D=0.008, p-value=0.933
# 01-25 12:31 nessai INFO    : it: 15000: Rolling KS test: D=0.024, p-value=0.5533
# 01-25 12:31 nessai INFO    : it: 15500: Rolling KS test: D=0.04, p-value=0.1966
# 01-25 12:31 nessai INFO    : it: 15620: n eval: 836485 H: 33.00 dlogZ: 54.575 logZ: -394.327 +/- 0.257 logLmax: -308.51
# 01-25 12:31 nessai INFO    : it: 16000: Rolling KS test: D=0.05, p-value=0.07937
# 01-25 12:31 nessai INFO    : it: 16500: Rolling KS test: D=0.06, p-value=0.02622
# 01-25 12:31 nessai INFO    : it: 17000: Rolling KS test: D=0.05, p-value=0.07937
# 01-25 12:32 nessai INFO    : it: 17500: Rolling KS test: D=0.046, p-value=0.1169
# 01-25 12:32 nessai INFO    : it: 17964: n eval: 965528 H: 36.07 dlogZ: 14.367 logZ: -355.863 +/- 0.269 logLmax: -305.57
# 01-25 12:32 nessai INFO    : it: 18000: Rolling KS test: D=0.028, p-value=0.4482
# 01-25 12:32 nessai INFO    : it: 18500: Rolling KS test: D=0.048, p-value=0.0967
# 01-25 12:32 nessai INFO    : it: 19000: Rolling KS test: D=0.048, p-value=0.0967
# 01-25 12:32 nessai INFO    : it: 19500: Rolling KS test: D=0.034, p-value=0.3078
# 01-25 12:33 nessai INFO    : it: 20000: Rolling KS test: D=0.01, p-value=0.8989
# 01-25 12:33 nessai INFO    : it: 20500: Rolling KS test: D=0.008, p-value=0.933
# 01-25 12:33 nessai INFO    : it: 20698: n eval: 1095528 H: 38.90 dlogZ: 2.300 logZ: -346.397 +/- 0.279 logLmax: -302.81
# 01-25 12:33 nessai INFO    : it: 21000: Rolling KS test: D=0.026, p-value=0.5
# 01-25 12:33 nessai INFO    : it: 21500: Rolling KS test: D=0.038, p-value=0.2301
# 01-25 12:33 nessai INFO    : it: 22000: Rolling KS test: D=0.038, p-value=0.2301
# 01-25 12:34 nessai INFO    : it: 22500: Rolling KS test: D=0.006, p-value=0.9608
# 01-25 12:34 nessai INFO    : it: 23000: Rolling KS test: D=0.03, p-value=0.3986
# 01-25 12:34 nessai INFO    : it: 23105: n eval: 1225528 H: 39.68 dlogZ: 0.057 logZ: -345.625 +/- 0.282 logLmax: -302.24
# 01-25 12:34 nessai INFO    : it: 23500: Rolling KS test: D=0.058, p-value=0.03325
# 01-25 12:34 nessai INFO    : it: 24000: Rolling KS test: D=0.034, p-value=0.3078
# 01-25 12:34 nessai INFO    : Stopping with dlogZ=0.010
# 01-25 12:34 nessai INFO    : Finalising
# 01-25 12:34 nessai INFO    : Final ln-evidence: -345.596 +/- 0.282
# 01-25 12:34 nessai INFO    : Information: 39.74
# 01-25 12:34 nessai INFO    : Final KS test: D=0.01222, p-value=0.0007608
# 01-25 12:34 nessai WARNING : Final p-value for the insertion indices is less than 0.05, this could be an indication of problems during sampling. Consider checking the diagnostic plots.
# 01-25 12:34 nessai INFO    : Checkpointing nested sampling
# 01-25 12:34 nessai INFO    : Total sampling time: 0:09:41.884242
# 01-25 12:34 nessai INFO    : Total training time: 0:00:29.081013
# 01-25 12:34 nessai INFO    : Total population time: 0:02:02.968633
# 01-25 12:34 nessai INFO    : Total likelihood evaluations: 1274896
# 01-25 12:34 nessai INFO    : Time spent evaluating likelihood: 0:06:26.560479
# 01-25 12:34 nessai INFO    : Total sampling time: 0:09:41.884242
# 01-25 12:34 nessai INFO    : Total likelihood evaluations: 1274896
# 01-25 12:34 nessai INFO    : Starting post processing
# 01-25 12:34 nessai INFO    : Computing posterior samples
# 01-25 12:34 nessai INFO    : Effective sample size: 3490.2
# 01-25 12:34 nessai INFO    : Producing posterior samples using rejection sampling
# 01-25 12:34 nessai INFO    : Expect 2323.958905287713 samples from rejection sampling
# 01-25 12:34 nessai INFO    : Returned 2341 posterior samples
# 01-25 12:34 nessai INFO    : Starting to close worker pool.
# 01-25 12:34 nessai INFO    : Finished closing worker pool.
# 12:34 bilby INFO    : Sampling time: 0:09:41.884242
# 12:34 bilby INFO    : Summary of results:
# nsamples: 2341
# ln_noise_evidence:    nan
# ln_evidence: -345.596 +/-  0.282
# ln_bayes_factor:    nan +/-  0.282

# %%
result.plot_corner(save=True)
